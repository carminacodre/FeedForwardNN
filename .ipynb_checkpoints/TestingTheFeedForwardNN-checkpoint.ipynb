# %% [markdown]
# # Test the implementation of the Feed Forward NN

# %%
import NotebookLoader
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
import FeedForwardNN as ff
reload(ff)
# Out:
# importing Jupyter notebook from FeedForwardNN.ipynb
# <module 'FeedForwardNN' from 'FeedForwardNN.ipynb'>

# %% [markdown]
# ## Test the implementation on mock data

# %%
# %matplotlib inline
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
y = np.array([y]).T
print("Data shape:" + str(y.shape))
# Out:
# Data shape:(200L, 1L)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
m = ff.Model2Layers(learning_rate = 0.8, input_dim= 2, output_dim=1, hidden_dim =5)
m.back_propagation(X,y)
# Out:
# Error    after 0 iterations:0.336960885152
# Accuracy after 0 iterations:1.0
# Error    after 10000 iterations:0.0160790132269
# Accuracy after 10000 iterations:1.0
# Error    after 20000 iterations:0.0113440622282
# Accuracy after 20000 iterations:1.0
# Error    after 30000 iterations:0.0137852590084
# Accuracy after 30000 iterations:1.0
# Error    after 40000 iterations:0.0121776696565
# Accuracy after 40000 iterations:1.0
# Error    after 50000 iterations:0.0127486359326
# Accuracy after 50000 iterations:1.0

# %%
m.predict(np.array([-1,1]))
# Out:
# 0

# %% [markdown]
# ## Test the implementation on iris dataset

# %%
iris = sklearn.datasets.load_iris()
X = iris["data"]
y_classes = iris["target"]
num_samples = X.shape[0]
num_classes = max(y_classes)+1

#one hot encoding
y = np.zeros((num_samples,num_classes))
y[range(num_samples),y_classes]=1

# %%
print("Classes of flowers " + str(iris.target_names))
print("Number of features for a sample " +str(X.shape[1]))
print("Total number of samples " +str(X.shape[0]))
# Out:
# Classes of flowers ['setosa' 'versicolor' 'virginica']
# Number of features for a sample 4
# Total number of samples 150

# %%
#10-fold cross validation for the iris dataset
k = 10
avg_acc= 0

for it in range(k):
    X_train = np.array([x for i, x in enumerate(X) if i % k != it])
    X_test = np.array([x for i, x in enumerate(X) if i % k == it])
    Y_train = np.array([x for i, x in enumerate(y) if i % k != it])
    Y_test = np.array([x for i, x in enumerate(y) if i % k == it])
    print("Cross validation %d" %it)
    
    m_iris = ff.Model2Layers(learning_rate = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
    m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
    
    predictions = m_iris.feed_forward(X_test)
    acc= m_iris.compute_accuracy(predictions, Y_test)
    avg_acc +=acc
    print("Accuracy for cross validation %d is %lf" %(it,acc))
avg_acc /= k
# Out:
# Cross validation 0
# Error    after 0 iterations:0.441689121936
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0971723808885
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0874663044122
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0844245356757
# Accuracy after 30000 iterations:0.955555555556
# Error    after 40000 iterations:0.0198962831015
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0108191709576
# Accuracy after 50000 iterations:0.992592592593
# Error    after 60000 iterations:0.00912381399315
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00836554499952
# Accuracy after 70000 iterations:0.992592592593
# Error    after 80000 iterations:0.00791074068498
# Accuracy after 80000 iterations:0.992592592593
# Error    after 90000 iterations:0.00759562165689
# Accuracy after 90000 iterations:0.992592592593
# Accuracy for cross validation 0 is 0.933333
# Cross validation 1
# Error    after 0 iterations:0.441694626868
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0981972217813
# Accuracy after 10000 iterations:0.881481481481
# Error    after 20000 iterations:0.0881684411902
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0506763272856
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0146209867395
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0119668567758
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0110210852224
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0104934194163
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0101315354175
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.00987736043002
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 1 is 1.000000
# Cross validation 2
# Error    after 0 iterations:0.441724998732
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0970185213641
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0874356596761
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.084482206504
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0231045832658
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0112303456634
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0092561078582
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00843738983835
# Accuracy after 70000 iterations:0.992592592593
# Error    after 80000 iterations:0.00793887580592
# Accuracy after 80000 iterations:0.992592592593
# Error    after 90000 iterations:0.00758493893851
# Accuracy after 90000 iterations:0.992592592593
# Accuracy for cross validation 2 is 0.933333
# Cross validation 3
# Error    after 0 iterations:0.441716918557
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0952672896399
# Accuracy after 10000 iterations:0.903703703704
# Error    after 20000 iterations:0.0861978573409
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0832342660629
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0123779933219
# Accuracy after 40000 iterations:0.992592592593
# Error    after 50000 iterations:0.00658926339053
# Accuracy after 50000 iterations:0.992592592593
# Error    after 60000 iterations:0.00503230938115
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00422801636019
# Accuracy after 70000 iterations:1.0
# Error    after 80000 iterations:0.00369794085633
# Accuracy after 80000 iterations:1.0
# Error    after 90000 iterations:0.00330421993608
# Accuracy after 90000 iterations:1.0
# Accuracy for cross validation 3 is 0.866667
# Cross validation 4
# Error    after 0 iterations:0.441697205343
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0973698764154
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0878659610699
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0849760087043
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0248877462522
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0131680827844
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0114311772057
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0107278462072
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.010322188471
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.0100347617188
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 4 is 1.000000
# Cross validation 5
# Error    after 0 iterations:0.441675682308
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0985635395859
# Accuracy after 10000 iterations:0.874074074074
# Error    after 20000 iterations:0.088381316391
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0853536721135
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0341924244431
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0139633082401
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0116790941748
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0108243787064
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.0103559013331
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.0100454938567
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 5 is 1.000000
# Cross validation 6
# Error    after 0 iterations:0.441694483445
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0968262946287
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0876869611731
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0207667723386
# Accuracy after 30000 iterations:0.977777777778
# Error    after 40000 iterations:0.0124791356475
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0109366881191
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0102661650938
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.00987445303127
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.00960694688331
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00940518285865
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 6 is 1.000000
# Cross validation 7
# Error    after 0 iterations:0.441700552738
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0959816025139
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0868992459264
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.0842050652509
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0210773726029
# Accuracy after 40000 iterations:0.97037037037
# Error    after 50000 iterations:0.0124320091887
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0109023295466
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0102625174587
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.00989601615696
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00964742865374
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 7 is 1.000000
# Cross validation 8
# Error    after 0 iterations:0.441705788342
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0956822903611
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0866786945871
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0839017095093
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0183444166498
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0118486834497
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0105639437802
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.0100025683904
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.00967490133438
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.00945290616642
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 8 is 1.000000
# Cross validation 9
# Error    after 0 iterations:0.441713351587
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0972720012453
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0875186105051
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0846558929513
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0206862965473
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0127614493011
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0113312616009
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0107424052792
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0104034779745
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0101679866275
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 9 is 1.000000

# %%
print("Average accuracy obtained by 10-fold cross-validation %fl"  %avg_acc)
# Out:
# Average accuracy obtained by 10-fold cross-validation 0.973333l

# %%
#Train with different lambda regularization

#Split 20% test a80% train
X_train = np.array([x for i, x in enumerate(X) if i % 5 != 0])
X_test = np.array([x for i, x in enumerate(X) if i % 5 == 0])
Y_train = np.array([x for i, x in enumerate(y) if i % 5 != 0])
Y_test = np.array([x for i, x in enumerate(y) if i % 5 == 0])

m_iris = ff.Model2Layers(learning_rate = 0.001, reg_lambda = 0.0005, input_dim= 4, output_dim=3, hidden_dim =5)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.0005 regularization factor %lf" %acc)

m_iris = ff.Model2Layers(learning_rate = 0.01, reg_lambda = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.001 regularization factor %lf" %acc)
# Out:
# Error    after 0 iterations:0.441658813542
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.102323005774
# Accuracy after 10000 iterations:0.85
# Error    after 20000 iterations:0.0896371740931
# Accuracy after 20000 iterations:0.941666666667
# Error    after 30000 iterations:0.0860831348861
# Accuracy after 30000 iterations:0.941666666667
# Error    after 40000 iterations:0.0815456162171
# Accuracy after 40000 iterations:0.95
# Error    after 50000 iterations:0.0172162892364
# Accuracy after 50000 iterations:0.983333333333
# Error    after 60000 iterations:0.0116270089513
# Accuracy after 60000 iterations:0.991666666667
# Error    after 70000 iterations:0.0100935670394
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.00933158043683
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.00885369672694
# Accuracy after 90000 iterations:0.991666666667
# Error    after 100000 iterations:0.00851474274783
# Accuracy after 100000 iterations:0.991666666667
# Error    after 110000 iterations:0.00825540201695
# Accuracy after 110000 iterations:0.991666666667
# Error    after 120000 iterations:0.00804664410531
# Accuracy after 120000 iterations:0.991666666667
# Error    after 130000 iterations:0.00787249269529
# Accuracy after 130000 iterations:0.991666666667
# Error    after 140000 iterations:0.00772339257813
# Accuracy after 140000 iterations:0.991666666667
# Error    after 150000 iterations:0.00759325663217
# Accuracy after 150000 iterations:0.991666666667
# Error    after 160000 iterations:0.00747800644095
# Accuracy after 160000 iterations:0.991666666667
# Error    after 170000 iterations:0.00737479222004
# Accuracy after 170000 iterations:0.991666666667
# Error    after 180000 iterations:0.00728154961621
# Accuracy after 180000 iterations:0.991666666667
# Error    after 190000 iterations:0.00719673530282
# Accuracy after 190000 iterations:0.991666666667
# Accuracy on test for 0.0005 regularization factor 0.966667
# Error    after 0 iterations:0.441658813542
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.102383794509
# Accuracy after 10000 iterations:0.85
# Error    after 20000 iterations:0.0897170199552
# Accuracy after 20000 iterations:0.941666666667
# Error    after 30000 iterations:0.0861824900207
# Accuracy after 30000 iterations:0.941666666667
# Error    after 40000 iterations:0.0765600990415
# Accuracy after 40000 iterations:0.958333333333
# Error    after 50000 iterations:0.0163678199072
# Accuracy after 50000 iterations:0.983333333333
# Error    after 60000 iterations:0.0115206048131
# Accuracy after 60000 iterations:0.991666666667
# Error    after 70000 iterations:0.0100950979668
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.00937232563548
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.0089163748405
# Accuracy after 90000 iterations:0.991666666667
# Error    after 100000 iterations:0.00859303887053
# Accuracy after 100000 iterations:0.991666666667
# Error    after 110000 iterations:0.0083464445504
# Accuracy after 110000 iterations:0.991666666667
# Error    after 120000 iterations:0.00814888759557
# Accuracy after 120000 iterations:0.991666666667
# Error    after 130000 iterations:0.00798496415892
# Accuracy after 130000 iterations:0.991666666667
# Error    after 140000 iterations:0.00784538275509
# Accuracy after 140000 iterations:0.991666666667
# Error    after 150000 iterations:0.00772418274541
# Accuracy after 150000 iterations:0.991666666667
# Error    after 160000 iterations:0.0076173487385
# Accuracy after 160000 iterations:0.991666666667
# Error    after 170000 iterations:0.00752206459423
# Accuracy after 170000 iterations:0.991666666667
# Error    after 180000 iterations:0.00743628662562
# Accuracy after 180000 iterations:0.991666666667
# Error    after 190000 iterations:0.00735848719896
# Accuracy after 190000 iterations:0.991666666667
# Accuracy on test for 0.001 regularization factor 0.966667
