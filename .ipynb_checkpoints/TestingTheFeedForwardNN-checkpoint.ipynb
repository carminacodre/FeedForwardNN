# %% [markdown]
# # Test the implementation of the Feed Forward NN

# %%
import NotebookLoader
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
import FeedForwardNN as ff
reload(ff)
# Out:
# importing Jupyter notebook from FeedForwardNN.ipynb
# <module 'FeedForwardNN' from 'FeedForwardNN.ipynb'>

# %% [markdown]
# ## Test the implementation on mock data

# %%
# %matplotlib inline
np.random.seed(0)
X, y = sklearn.datasets.make_moons(200, noise=0.20)
y = np.array([y]).T
print("Data shape:" + str(y.shape))
# Out:
# Data shape:(200L, 1L)

# %%
plt.scatter(X[:,0], X[:,1], c=y)

# %%
m = ff.Model2Layers(learning_rate = 0.8, input_dim= 2, output_dim=1, hidden_dim =5)
m.back_propagation(X,y)
# Out:
# Error    after 0 iterations:0.336960885152
# Accuracy after 0 iterations:1.0
# Error    after 10000 iterations:0.0160790132269
# Accuracy after 10000 iterations:1.0
# Error    after 20000 iterations:0.0113440622282
# Accuracy after 20000 iterations:1.0
# Error    after 30000 iterations:0.0137852590084
# Accuracy after 30000 iterations:1.0
# Error    after 40000 iterations:0.0121776696565
# Accuracy after 40000 iterations:1.0
# Error    after 50000 iterations:0.0127486359326
# Accuracy after 50000 iterations:1.0

# %%
m.predict(np.array([-1,1]))
# Out:
# 0

# %% [markdown]
# ## Test the implementation on iris dataset

# %%
iris = sklearn.datasets.load_iris()
X = iris["data"]
y_classes = iris["target"]
num_samples = X.shape[0]
num_classes = max(y_classes)+1

#one hot encoding
y = np.zeros((num_samples,num_classes))
y[range(num_samples),y_classes]=1

# %%
print("Classes of flowers " + str(iris.target_names))
print("Features " + str(iris.feature_names))
print("Number of features for a sample " +str(X.shape[1]))
print("Total number of samples " +str(X.shape[0]))
print(X[0:5])
# Out:
# Classes of flowers ['setosa' 'versicolor' 'virginica']
# Features ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
# Number of features for a sample 4
# Total number of samples 150
# [[ 5.1  3.5  1.4  0.2]
#  [ 4.9  3.   1.4  0.2]
#  [ 4.7  3.2  1.3  0.2]
#  [ 4.6  3.1  1.5  0.2]
#  [ 5.   3.6  1.4  0.2]]

# %%
#Sepal length and sepal width plot

x_min, x_max = X[:, 0].min() - .5, X[:, 0].max() + .5
y_min, y_max = X[:, 1].min() - .5, X[:, 1].max() + .5

plt.figure(1, figsize=(8, 6))

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())

#SPetal length and Petal width plot

x_min, x_max = X[:, 2].min() - .5, X[:, 2].max() + .5
y_min, y_max = X[:, 3].min() - .5, X[:, 3].max() + .5

plt.figure(2, figsize=(8, 6))

# Plot the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Set1,
            edgecolor='k')
plt.xlabel('Petal length')
plt.ylabel('Petal width')

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %% [markdown]
# ### Compute accuracy using 10-fold crossvalidation

# %%
#10-fold cross validation for the iris dataset
k = 10
avg_acc_n= 0

for it in range(k):
    X_train = np.array([x for i, x in enumerate(X) if i % k != it])
    X_test = np.array([x for i, x in enumerate(X) if i % k == it])
    Y_train = np.array([x for i, x in enumerate(y) if i % k != it])
    Y_test = np.array([x for i, x in enumerate(y) if i % k == it])
    print("Cross validation %d" %it)
    
    m_iris = ff.Model2Layers(learning_rate = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
    m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
    
    predictions = m_iris.feed_forward(X_test)
    acc= m_iris.compute_accuracy(predictions, Y_test)
    avg_acc_n +=acc
    print("Accuracy for cross validation %d is %lf" %(it,acc))
avg_acc_n /= k
# Out:
# Cross validation 0
# Error    after 0 iterations:0.441689121936
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0971723808885
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0874663044122
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0844245356757
# Accuracy after 30000 iterations:0.955555555556
# Error    after 40000 iterations:0.0198962831015
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0108191709576
# Accuracy after 50000 iterations:0.992592592593
# Error    after 60000 iterations:0.00912381399315
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00836554499952
# Accuracy after 70000 iterations:0.992592592593
# Error    after 80000 iterations:0.00791074068498
# Accuracy after 80000 iterations:0.992592592593
# Error    after 90000 iterations:0.00759562165689
# Accuracy after 90000 iterations:0.992592592593
# Accuracy for cross validation 0 is 0.933333
# Cross validation 1
# Error    after 0 iterations:0.441694626868
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0981972217813
# Accuracy after 10000 iterations:0.881481481481
# Error    after 20000 iterations:0.0881684411902
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0506763272856
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0146209867395
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0119668567758
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0110210852224
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0104934194163
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0101315354175
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.00987736043002
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 1 is 1.000000
# Cross validation 2
# Error    after 0 iterations:0.441724998732
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0970185213641
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0874356596761
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.084482206504
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0231045832658
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0112303456634
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0092561078582
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00843738983835
# Accuracy after 70000 iterations:0.992592592593
# Error    after 80000 iterations:0.00793887580592
# Accuracy after 80000 iterations:0.992592592593
# Error    after 90000 iterations:0.00758493893851
# Accuracy after 90000 iterations:0.992592592593
# Accuracy for cross validation 2 is 0.933333
# Cross validation 3
# Error    after 0 iterations:0.441716918557
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0952672896399
# Accuracy after 10000 iterations:0.903703703704
# Error    after 20000 iterations:0.0861978573409
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0832342660629
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0123779933219
# Accuracy after 40000 iterations:0.992592592593
# Error    after 50000 iterations:0.00658926339053
# Accuracy after 50000 iterations:0.992592592593
# Error    after 60000 iterations:0.00503230938115
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00422801636019
# Accuracy after 70000 iterations:1.0
# Error    after 80000 iterations:0.00369794085633
# Accuracy after 80000 iterations:1.0
# Error    after 90000 iterations:0.00330421993608
# Accuracy after 90000 iterations:1.0
# Accuracy for cross validation 3 is 0.866667
# Cross validation 4
# Error    after 0 iterations:0.441697205343
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0973698764154
# Accuracy after 10000 iterations:0.888888888889
# Error    after 20000 iterations:0.0878659610699
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0849760087043
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0248877462522
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0131680827844
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0114311772057
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0107278462072
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.010322188471
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.0100347617188
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 4 is 1.000000
# Cross validation 5
# Error    after 0 iterations:0.441675682308
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0985635395859
# Accuracy after 10000 iterations:0.874074074074
# Error    after 20000 iterations:0.088381316391
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0853536721135
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0341924244431
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0139633082401
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0116790941748
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0108243787064
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.0103559013331
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.0100454938567
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 5 is 1.000000
# Cross validation 6
# Error    after 0 iterations:0.441694483445
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0968262946287
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0876869611731
# Accuracy after 20000 iterations:0.948148148148
# Error    after 30000 iterations:0.0207667723386
# Accuracy after 30000 iterations:0.977777777778
# Error    after 40000 iterations:0.0124791356475
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0109366881191
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0102661650938
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.00987445303127
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.00960694688331
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00940518285865
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 6 is 1.000000
# Cross validation 7
# Error    after 0 iterations:0.441700552738
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0959816025139
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0868992459264
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.0842050652509
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0210773726029
# Accuracy after 40000 iterations:0.97037037037
# Error    after 50000 iterations:0.0124320091887
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0109023295466
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0102625174587
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.00989601615696
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00964742865374
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 7 is 1.000000
# Cross validation 8
# Error    after 0 iterations:0.441705788342
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0956822903611
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0866786945871
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0839017095093
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0183444166498
# Accuracy after 40000 iterations:0.985185185185
# Error    after 50000 iterations:0.0118486834497
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0105639437802
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.0100025683904
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.00967490133438
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.00945290616642
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 8 is 1.000000
# Cross validation 9
# Error    after 0 iterations:0.441713351587
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0972720012453
# Accuracy after 10000 iterations:0.896296296296
# Error    after 20000 iterations:0.0875186105051
# Accuracy after 20000 iterations:0.955555555556
# Error    after 30000 iterations:0.0846558929513
# Accuracy after 30000 iterations:0.962962962963
# Error    after 40000 iterations:0.0206862965473
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0127614493011
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0113312616009
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0107424052792
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0104034779745
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0101679866275
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 9 is 1.000000

# %%
print("Average accuracy obtained by 10-fold cross-validation %fl"  %avg_acc_n)
# Out:
# Average accuracy obtained by 10-fold cross-validation 0.973333l

# %% [markdown]
# ### Test normalization of the data

# %%
#10-fold cross validation for the iris dataset normalized
k = 10
avg_acc= 0

X_normalized = X.copy()
y_normalized = y.copy()

X_normalized[:, 0] = (X_normalized[:,0]-min(X_normalized[:,0]))/(max(X_normalized[:,0])-min(X_normalized[:,0]))
X_normalized[:, 1] = (X_normalized[:,1]-min(X_normalized[:,1]))/(max(X_normalized[:,1])-min(X_normalized[:,1]))
X_normalized[:, 2] = (X_normalized[:,2]-min(X_normalized[:,2]))/(max(X_normalized[:,2])-min(X_normalized[:,2]))
X_normalized[:, 3] = (X_normalized[:,3]-min(X_normalized[:,3]))/(max(X_normalized[:,3])-min(X_normalized[:,3]))

print(X_normalized[0:5])

for it in range(k):
    X_train = np.array([x for i, x in enumerate(X_normalized) if i % k != it])
    X_test = np.array([x for i, x in enumerate(X_normalized) if i % k == it])
    Y_train = np.array([x for i, x in enumerate(y_normalized) if i % k != it])
    Y_test = np.array([x for i, x in enumerate(y_normalized) if i % k == it])
    print("Cross validation %d" %it)
    
    m_iris = ff.Model2Layers(learning_rate = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
    m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
    
    predictions = m_iris.feed_forward(X_test)
    acc= m_iris.compute_accuracy(predictions, Y_test)
    avg_acc +=acc
    print("Accuracy for cross validation %d is %lf" %(it,acc))
avg_acc /= k
# Out:
# [[ 0.22222222  0.625       0.06779661  0.04166667]
#  [ 0.16666667  0.41666667  0.06779661  0.04166667]
#  [ 0.11111111  0.5         0.05084746  0.04166667]
#  [ 0.08333333  0.45833333  0.08474576  0.04166667]
#  [ 0.19444444  0.66666667  0.06779661  0.04166667]]
# Cross validation 0
# Error    after 0 iterations:0.378863913203
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0661002625168
# Accuracy after 10000 iterations:0.962962962963
# Error    after 20000 iterations:0.0196005390762
# Accuracy after 20000 iterations:0.977777777778
# Error    after 30000 iterations:0.013280679933
# Accuracy after 30000 iterations:0.977777777778
# Error    after 40000 iterations:0.0111805883672
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0101200165035
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.00948670375002
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.00907234946785
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.008783681012
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00857257357183
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 0 is 0.933333
# Cross validation 1
# Error    after 0 iterations:0.378986386309
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0661280168553
# Accuracy after 10000 iterations:0.948148148148
# Error    after 20000 iterations:0.0210847346574
# Accuracy after 20000 iterations:0.97037037037
# Error    after 30000 iterations:0.015130364181
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0130854318871
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0120202336132
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0113727520994
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0109465238859
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0106500465313
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0104346914037
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 1 is 1.000000
# Cross validation 2
# Error    after 0 iterations:0.378859120673
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0708201952103
# Accuracy after 10000 iterations:0.962962962963
# Error    after 20000 iterations:0.0204121769231
# Accuracy after 20000 iterations:0.97037037037
# Error    after 30000 iterations:0.0141133512367
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0121438035195
# Accuracy after 40000 iterations:0.97037037037
# Error    after 50000 iterations:0.0111587920965
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0105684869438
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.010181216465
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.00991144896843
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00971456226894
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 2 is 1.000000
# Cross validation 3
# Error    after 0 iterations:0.379199460632
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0655912082213
# Accuracy after 10000 iterations:0.962962962963
# Error    after 20000 iterations:0.0170326742164
# Accuracy after 20000 iterations:0.985185185185
# Error    after 30000 iterations:0.0105860028397
# Accuracy after 30000 iterations:0.992592592593
# Error    after 40000 iterations:0.00823196944928
# Accuracy after 40000 iterations:0.992592592593
# Error    after 50000 iterations:0.00692056439183
# Accuracy after 50000 iterations:0.992592592593
# Error    after 60000 iterations:0.00606705439383
# Accuracy after 60000 iterations:0.992592592593
# Error    after 70000 iterations:0.00546261424952
# Accuracy after 70000 iterations:0.992592592593
# Error    after 80000 iterations:0.00500795585455
# Accuracy after 80000 iterations:0.992592592593
# Error    after 90000 iterations:0.00464939658915
# Accuracy after 90000 iterations:1.0
# Accuracy for cross validation 3 is 0.866667
# Cross validation 4
# Error    after 0 iterations:0.378961972553
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0650455115364
# Accuracy after 10000 iterations:0.948148148148
# Error    after 20000 iterations:0.0198523192339
# Accuracy after 20000 iterations:0.97037037037
# Error    after 30000 iterations:0.0144356923082
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0127514853295
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0118908075048
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0113477743345
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0109683593606
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.010687928952
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0104731991481
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 4 is 1.000000
# Cross validation 5
# Error    after 0 iterations:0.378663250141
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0705941379333
# Accuracy after 10000 iterations:0.962962962963
# Error    after 20000 iterations:0.0217795607637
# Accuracy after 20000 iterations:0.97037037037
# Error    after 30000 iterations:0.0152817025065
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0131548434741
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0120626768878
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.011402017878
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0109680323132
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0106665438588
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0104477603883
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 5 is 1.000000
# Cross validation 6
# Error    after 0 iterations:0.379023246569
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0654251938367
# Accuracy after 10000 iterations:0.955555555556
# Error    after 20000 iterations:0.0195642008295
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.0142387149204
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.012381278198
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0113950841628
# Accuracy after 50000 iterations:0.985185185185
# Error    after 60000 iterations:0.0107885897055
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.0103873865633
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.0101084087526
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00990656713373
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 6 is 1.000000
# Cross validation 7
# Error    after 0 iterations:0.378895319875
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0667807745237
# Accuracy after 10000 iterations:0.962962962963
# Error    after 20000 iterations:0.0191782671134
# Accuracy after 20000 iterations:0.977777777778
# Error    after 30000 iterations:0.0135161634884
# Accuracy after 30000 iterations:0.977777777778
# Error    after 40000 iterations:0.0116684062262
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0107269484492
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0101631675094
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0097968089732
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.00954533588113
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.00936524340096
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 7 is 1.000000
# Cross validation 8
# Error    after 0 iterations:0.37895608307
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.070367310036
# Accuracy after 10000 iterations:0.97037037037
# Error    after 20000 iterations:0.0196643770204
# Accuracy after 20000 iterations:0.97037037037
# Error    after 30000 iterations:0.0135128196938
# Accuracy after 30000 iterations:0.97037037037
# Error    after 40000 iterations:0.0116857161739
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.010804284481
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0102792977277
# Accuracy after 60000 iterations:0.985185185185
# Error    after 70000 iterations:0.00992961412535
# Accuracy after 70000 iterations:0.985185185185
# Error    after 80000 iterations:0.00968045378822
# Accuracy after 80000 iterations:0.985185185185
# Error    after 90000 iterations:0.00949481142536
# Accuracy after 90000 iterations:0.985185185185
# Accuracy for cross validation 8 is 1.000000
# Cross validation 9
# Error    after 0 iterations:0.379215152987
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0658362290351
# Accuracy after 10000 iterations:0.955555555556
# Error    after 20000 iterations:0.0199170274593
# Accuracy after 20000 iterations:0.962962962963
# Error    after 30000 iterations:0.0142449128525
# Accuracy after 30000 iterations:0.977777777778
# Error    after 40000 iterations:0.0124175651072
# Accuracy after 40000 iterations:0.977777777778
# Error    after 50000 iterations:0.0114890571228
# Accuracy after 50000 iterations:0.977777777778
# Error    after 60000 iterations:0.0109302557372
# Accuracy after 60000 iterations:0.977777777778
# Error    after 70000 iterations:0.0105661006827
# Accuracy after 70000 iterations:0.977777777778
# Error    after 80000 iterations:0.0103159736183
# Accuracy after 80000 iterations:0.977777777778
# Error    after 90000 iterations:0.0101366740737
# Accuracy after 90000 iterations:0.977777777778
# Accuracy for cross validation 9 is 1.000000

# %%
print("Average accuracy obtained by 10-fold cross-validation on normalized data %fl"  %avg_acc)
# Out:
# Average accuracy obtained by 10-fold cross-validation on normalized data 0.980000l

# %% [markdown]
# ### Train with different regularization factor

# %%
#Split 20% test a80% train

np.random.shuffle(X[0:50])
np.random.shuffle(X[50:100])
np.random.shuffle(X[100:150])

X_train = np.array([x for i, x in enumerate(X) if i % 5 != 0])
X_test = np.array([x for i, x in enumerate(X) if i % 5 == 0])
Y_train = np.array([x for i, x in enumerate(y) if i % 5 != 0])
Y_test = np.array([x for i, x in enumerate(y) if i % 5 == 0])

# %%
m_iris = ff.Model2Layers(learning_rate = 0.001, reg_lambda = 0.0005, input_dim= 4, output_dim=3, hidden_dim =5)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.0005 regularization factor %lf" %acc)

m_iris = ff.Model2Layers(learning_rate = 0.01, reg_lambda = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.001 regularization factor %lf" %acc)
# Out:
# Error    after 0 iterations:0.441726030141
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.0980581765134
# Accuracy after 10000 iterations:0.891666666667
# Error    after 20000 iterations:0.0877514450936
# Accuracy after 20000 iterations:0.95
# Error    after 30000 iterations:0.0845985863856
# Accuracy after 30000 iterations:0.958333333333
# Error    after 40000 iterations:0.0357030783659
# Accuracy after 40000 iterations:0.983333333333
# Error    after 50000 iterations:0.00999170303178
# Accuracy after 50000 iterations:0.983333333333
# Error    after 60000 iterations:0.00718675521681
# Accuracy after 60000 iterations:0.983333333333
# Error    after 70000 iterations:0.00612876390375
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.00553768042198
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.00514199052898
# Accuracy after 90000 iterations:1.0
# Accuracy on test for 0.0005 regularization factor 0.966667
# Error    after 0 iterations:0.441726030141
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.00666764706887
# Accuracy after 10000 iterations:0.983333333333
# Error    after 20000 iterations:0.00492113638286
# Accuracy after 20000 iterations:0.991666666667
# Error    after 30000 iterations:0.00400528401551
# Accuracy after 30000 iterations:1.0
# Error    after 40000 iterations:0.00322287732242
# Accuracy after 40000 iterations:1.0
# Error    after 50000 iterations:0.00444168458173
# Accuracy after 50000 iterations:0.983333333333
# Error    after 60000 iterations:0.00502057088865
# Accuracy after 60000 iterations:0.983333333333
# Error    after 70000 iterations:0.00467250181479
# Accuracy after 70000 iterations:0.983333333333
# Error    after 80000 iterations:0.00441702446495
# Accuracy after 80000 iterations:0.983333333333
# Error    after 90000 iterations:0.00420726009146
# Accuracy after 90000 iterations:0.983333333333
# Accuracy on test for 0.001 regularization factor 0.966667

# %% [markdown]
# ### Train with different hidden layer sizes

# %%
m_iris = ff.Model2Layers(learning_rate = 0.001, reg_lambda = 0.001, input_dim= 4, output_dim=3, hidden_dim =3)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.0005 regularization factor %lf" %acc)

m_iris = ff.Model2Layers(learning_rate = 0.01, reg_lambda = 0.001, input_dim= 4, output_dim=3, hidden_dim =7)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
predictions = m_iris.feed_forward(X_test)
acc= m_iris.compute_accuracy(predictions, Y_test)
print("Accuracy on test for 0.001 regularization factor %lf" %acc)
# Out:
# Error    after 0 iterations:0.418371524099
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.022363513761
# Accuracy after 10000 iterations:0.983333333333
# Error    after 20000 iterations:0.0135328848098
# Accuracy after 20000 iterations:0.983333333333
# Error    after 30000 iterations:0.0113679338901
# Accuracy after 30000 iterations:0.983333333333
# Error    after 40000 iterations:0.0103241420756
# Accuracy after 40000 iterations:0.991666666667
# Error    after 50000 iterations:0.00968913043188
# Accuracy after 50000 iterations:0.991666666667
# Error    after 60000 iterations:0.00925192263628
# Accuracy after 60000 iterations:0.991666666667
# Error    after 70000 iterations:0.00892669174547
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.0086716535065
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.00846389166317
# Accuracy after 90000 iterations:0.991666666667
# Accuracy on test for 0.0005 regularization factor 0.966667
# Error    after 0 iterations:0.386069834087
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.00818474464274
# Accuracy after 10000 iterations:0.991666666667
# Error    after 20000 iterations:0.00725523018726
# Accuracy after 20000 iterations:0.991666666667
# Error    after 30000 iterations:0.00680505927747
# Accuracy after 30000 iterations:0.991666666667
# Error    after 40000 iterations:0.00653700375166
# Accuracy after 40000 iterations:0.991666666667
# Error    after 50000 iterations:0.00636674045703
# Accuracy after 50000 iterations:0.991666666667
# Error    after 60000 iterations:0.0062517302509
# Accuracy after 60000 iterations:0.991666666667
# Error    after 70000 iterations:0.0061699393077
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.00610999980078
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.00606522066732
# Accuracy after 90000 iterations:0.991666666667
# Accuracy on test for 0.001 regularization factor 0.966667

# %% [markdown]
# ### Make predictions

# %%
m_iris = ff.Model2Layers(learning_rate = 0.001, reg_lambda = 0.001, input_dim= 4, output_dim=3, hidden_dim =5)
m_iris.back_propagation(X_train,Y_train, no_iterations = 100000)
# Out:
# Error    after 0 iterations:0.441680133712
# Accuracy after 0 iterations:0.333333333333
# Error    after 10000 iterations:0.100166967542
# Accuracy after 10000 iterations:0.866666666667
# Error    after 20000 iterations:0.0886816182376
# Accuracy after 20000 iterations:0.95
# Error    after 30000 iterations:0.0852805444537
# Accuracy after 30000 iterations:0.95
# Error    after 40000 iterations:0.0407808792451
# Accuracy after 40000 iterations:0.983333333333
# Error    after 50000 iterations:0.0108564041708
# Accuracy after 50000 iterations:0.983333333333
# Error    after 60000 iterations:0.00767042464838
# Accuracy after 60000 iterations:0.983333333333
# Error    after 70000 iterations:0.0064916183399
# Accuracy after 70000 iterations:0.991666666667
# Error    after 80000 iterations:0.00584108230362
# Accuracy after 80000 iterations:0.991666666667
# Error    after 90000 iterations:0.00540965703205
# Accuracy after 90000 iterations:0.991666666667

# %%
sample_test = 0
print([str((i,x)) for x,i in zip(X_test[sample_test],iris.feature_names)])
pred = m_iris.predict(X_test[0])
print("Predicted    %d -> %s" %(pred ,iris.target_names[pred]))
actual = np.argmax(Y_test[sample_test])
print("Actual class %d -> %s" %(actual,iris.target_names[actual]))
# Out:
# ["('sepal length (cm)', 4.7000000000000002)", "('sepal width (cm)', 3.2000000000000002)", "('petal length (cm)', 1.6000000000000001)", "('petal width (cm)', 0.20000000000000001)"]
# Predicted    0 -> setosa
# Actual class 0 -> setosa
